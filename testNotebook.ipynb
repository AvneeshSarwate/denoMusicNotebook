// %%
import { add } from "./main.ts";

console.log("Add 2 + 3 =", add(2, 3));
// Out:
// Add 2 + 3 = 5

// %%
import { launch } from "./copiedHelpers/offline_time_context.ts"

launch(async ctx => {
  for (let i = 0; i < 50; i++) {
    console.log(ctx.time, i)
    await ctx.waitSec(0.3)
  }
})
// Out:
// 0 0
// <ref *2> CancelablePromiseProxy [[object CancelablePromiseProxy]] {
//   promise: Promise { <pending> },
//   abortController: AbortController {
//     signal: AbortSignal { aborted: false, reason: undefined, onabort: null }
//   },
//   timeContext: <ref *1> DateTimeContext {
//     rootContext: [Circular *1],
//     mostRecentDescendentTime: 0,
//     debugName: "",
//     abortController: AbortController {
//       signal: AbortSignal { aborted: false, reason: undefined, onabort: null }
//     },
//     time: 0,
//     startTime: 0,
//     isCanceled: false,
//     id: 1,
//     cancelPromise: [Circular *2],
//     childContexts: Set(0) {},
//     scheduler: TimeScheduler {
//       id: "1cdd3d65-2546-45ed-a382-5de2106af5e8",
//       mode: "realtime",
//       lastProcessedTime: 0,
//       inTimesliceMicrotaskPhase: false,
//       seqCounter: 1,
//       timePQ: PriorityQueue {
//         heap: [ [Object] ],
//         idToIndex: Map(1) { "time:0" => 0 },
//         logWarnings: false
//       },
//       beatPQs: Map(0) {},
//       tempoHeadPQ: PriorityQueue {
//         heap: [],
//         idToIndex: Map(0) {},
//         logWarnings: false
//       },
//       frameWaiters: Map(0) {},
//       timeoutId: 7,
//       pumpQueued: false,
//       rate: 1,
//       wallAnchor: 27.748434500000002,
//       logicalAnchor: 0,
//       offlineNow: 0,
//       rafRunning: false,
//       rafHandle: null,
//       pumpMacroQueued: false
//     },
//     tempo: TempoMap {
//       id: "41dd8703-977a-40aa-85eb-c6069a8020e7",
//       version: 0,
//       segs: [
//         {
//           t0: 0,
//           t1: Infinity,
//           bpm0: 60,
//           bpm1: 60,
//           beats0: 0,
//           beats1: Infinity
//         }
//       ]
//     },
//     rng: [Function: prng] {
//       double: [Function (anonymous)],
//       quick: [Function (anonymous)],
//       int32: [Function (anonymous)],
//       state: [Function (anonymous)]
//     },
//     rngSeed: "4864b351-2ac4-442b-a93b-d643ca09640b",
//     rngForkCounter: 0
//   },
//   [Symbol(Symbol.toStringTag)]: "[object CancelablePromiseProxy]"
// }
// 0.3 1
// 0.6 2
// 0.8999999999999999 3
// 1.2 4
// 1.5 5
// 1.8 6
// 2.1 7
// 2.4 8
// 2.6999999999999997 9
// 2.9999999999999996 10
// 3.2999999999999994 11
// 3.599999999999999 12
// 3.899999999999999 13
// 4.199999999999999 14
// 4.499999999999999 15
// 4.799999999999999 16
// 5.099999999999999 17
// 5.399999999999999 18
// 5.699999999999998 19
// 5.999999999999998 20
// 6.299999999999998 21
// 6.599999999999998 22
// 6.899999999999998 23
// 7.1999999999999975 24
// 7.499999999999997 25
// 7.799999999999997 26
// 8.099999999999998 27
// 8.399999999999999 28
// 8.7 29
// 9 30
// 9.3 31
// 9.600000000000001 32
// 9.900000000000002 33
// 10.200000000000003 34
// 10.500000000000004 35
// 10.800000000000004 36
// 11.100000000000005 37
// 11.400000000000006 38
// 11.700000000000006 39
// 12.000000000000007 40
// 12.300000000000008 41
// 12.600000000000009 42
// 12.90000000000001 43
// 13.20000000000001 44
// 13.50000000000001 45
// 13.800000000000011 46
// 14.100000000000012 47
// 14.400000000000013 48
// 14.700000000000014 49
