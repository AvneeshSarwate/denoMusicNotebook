// %%
import { add } from "./main.ts";
const r = Math.random()
console.log(`Add 2 + ${r} = ${add(2, r)}`);
// Out:
// Add 2 + 0.6346543469510569 = 2.634654346951057

// %%
import { launch } from "./copiedHelpers/offline_time_context.ts"

launch(async ctx => {
  for (let i = 0; i < 50; i++) {
    console.log(ctx.time, i)
    await ctx.waitSec(0.3)
  }
})

null
// Out:
// 0 0
// null
// 0.3 1
// 0.6 2
// 0.8999999999999999 3
// 1.2 4
// 1.5 5
// 1.8 6
// 2.1 7
// 2.4 8
// 2.6999999999999997 9
// 2.9999999999999996 10
// 3.2999999999999994 11
// 3.599999999999999 12
// 3.899999999999999 13
// 4.199999999999999 14
// 4.499999999999999 15
// 4.799999999999999 16
// 5.099999999999999 17
// 5.399999999999999 18
// 5.699999999999998 19
// 5.999999999999998 20
// 6.299999999999998 21
// 6.599999999999998 22
// 6.899999999999998 23
// 7.1999999999999975 24
// 7.499999999999997 25
// 7.799999999999997 26
// 8.099999999999998 27
// 8.399999999999999 28
// 8.7 29
// 9 30
// 9.3 31
// 9.600000000000001 32
// 9.900000000000002 33
// 10.200000000000003 34
// 10.500000000000004 35
// 10.800000000000004 36
// 11.100000000000005 37
// 11.400000000000006 38
// 11.700000000000006 39
// 12.000000000000007 40
// 12.300000000000008 41
// 12.600000000000009 42
// 12.90000000000001 43
// 13.20000000000001 44
// 13.50000000000001 45
// 13.800000000000011 46
// 14.100000000000012 47
// 14.400000000000013 48
// 14.700000000000014 49

// %%
import {
  clipMap,
  showMelody,
  showBoundMelody,
  PianoRollHandle,
  initializePianoRollBridge
} from "./pianoRollBridge.ts"
import { AbletonClip, quickNote } from "./copiedHelpers/AbletonClip.ts"

const serverInfo = initializePianoRollBridge()
console.log("Piano Roll Server URL:", serverInfo.baseUrl)
console.log("Is new server:", serverInfo.isNewServer)
// Out:
// [PianoRollBridge] Initializing server...
// [PianoRollBridge] Server running at http://0.0.0.0:51753
// [PianoRollBridge] Server ready at http://127.0.0.1:51753
// Piano Roll Server URL: http://127.0.0.1:51753
// Is new server: true

// %%
// Create a simple melody
const simpleClip = new AbletonClip("Simple Melody", 4, [
  quickNote(60, 0.5, 100, 0),    // C
  quickNote(62, 0.5, 100, 0.5),  // D
  quickNote(64, 0.5, 100, 1),    // E
  quickNote(65, 0.5, 100, 1.5),  // F
  quickNote(67, 1, 100, 2),      // G
])

// Display as read-only (user cannot edit)
showMelody(simpleClip)
// Out:
// <iframe
//     src="http://127.0.0.1:51753/editor?id=session_1766720838976_075z5ee51"
//     width="680"
//     height="460"
//     style="border: 1px solid #ccc; border-radius: 8px; background: white;"
//   ></iframe>

// %%
// Create a clip and add it to the ClipMap
const editableClip = new AbletonClip("Editable Melody", 8, [
  quickNote(64, 1, 100, 0),     // E
  quickNote(62, 1, 100, 1),     // D
  quickNote(60, 1, 100, 2),     // C
  quickNote(62, 1, 100, 3),     // D
  quickNote(64, 1, 100, 4),     // E
  quickNote(64, 1, 100, 5),     // E
  quickNote(64, 2, 100, 6),     // E (longer)
])

clipMap.set("myMelody", editableClip)

// Display editable piano roll
const handle = showBoundMelody(clipMap, "myMelody")
null
// Out:
// <iframe
//     src="http://127.0.0.1:51753/editor?id=session_1766720848739_hwtm240hw"
//     width="680"
//     height="460"
//     style="border: 1px solid #ccc; border-radius: 8px; background: white;"
//   ></iframe>
// null

// %%
handle.latestClip!.notes.map(n => n.pitch)
// Out:
// [ 64, 66, 64, 64, 64 ]

// %%
showBoundMelody(clipMap, "myMelody")
// Out:
// <iframe
//     src="http://127.0.0.1:51753/editor?id=session_1766720866115_eclynmctn"
//     width="680"
//     height="460"
//     style="border: 1px solid #ccc; border-radius: 8px; background: white;"
//   ></iframe>
// {
//   latestClip: [Getter],
//   disconnect: [Function: disconnect],
//   setLivePlayhead: [Function: setLivePlayhead],
//   fitZoomToNotes: [Function: fitZoomToNotes]
// }
